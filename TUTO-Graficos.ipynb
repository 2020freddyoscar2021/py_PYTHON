# %%
import pandas as pd

# %%
##Importar archivo CSV
df = pd.read_csv('listaclase - Hoja 3.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\User\py_Codigo\py_PYTHON\TUTO-Graficos.ipynb Celda 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/py_Codigo/py_PYTHON/TUTO-Graficos.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> ##Importar archivo CSV
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/py_Codigo/py_PYTHON/TUTO-Graficos.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv('listaclase - Hoja 3.csv')
#
# File c:\Users\User\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
##Ver la tabla
df.sample(10)
# Out:
#              Nombre  Edad  Peso  Altura  Genero
# 16     Samuel Gómez    21    67    1.71  Hombre
# 23    Violeta Durán    24    49    1.56   Mujer
# 4      Jorge  Ortíz    20    60    1.70  Hombre
# 3   Maria Domínguez    20    52    1.60   Mujer
# 24  Valentín Acosta    23    80    1.82  Hombre
# 22      Vanesa Díaz    25    63    1.63   Mujer
# 2     Erick Estrada    20    65    1.74  Hombre
# 9      Alicia López    19    62    1.65   Mujer
# 13     Lily Ramírez    23    55    1.50   Mujer
# 19    Sofia Padilla    18    69    1.70   Mujer

# %%
##Ver estadistica simple
df.describe()
# Out:
#             Edad       Peso     Altura
# count  25.000000  25.000000  25.000000
# mean   21.440000  64.160000   1.678400
# std     2.042874   8.091559   0.086827
# min    18.000000  49.000000   1.500000
# 25%    20.000000  59.000000   1.610000
# 50%    21.000000  65.000000   1.700000
# 75%    23.000000  70.000000   1.740000
# max    25.000000  80.000000   1.820000

# %%
##Grafico de puntos o dispercion
df.plot.scatter(y='Altura', x='Peso')
# Out:
# <AxesSubplot:xlabel='Peso', ylabel='Altura'>

# %%
##conteos por registro y grafico pastel
serie = df.Genero.value_counts()
serie.plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Genero'>

# %%
#grafico barras y volterar forma vertical y ordenar forma ascendente mayor a menor valor
serie_edad = df.Edad.value_counts()
serie_edad = serie_edad.sort_values(ascending=True)
serie_edad.plot.barh()
# Out:
# <AxesSubplot:>

# %%
##ordena por numero mayor a menor index
serie_edad = df.Edad.value_counts()
serie_edad = serie_edad.sort_index(ascending=True)
serie_edad.plot.barh()
# Out:
# <AxesSubplot:>

# %%
##Graficas Distribucion, Histograma, caja y Densidad
df.Altura.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Altura.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.Altura.plot.box()
# Out:
# <AxesSubplot:>

# %%
#grafico de columnas colore
import seaborn as sb
import numpy as np

barras = ["chocolate","fresa","vainilla","pistacho"] # sabores de helados
preferencias = np.array([12,18,20,4]) # cuantos prefieren cada sabor
sb.set(font_scale = 1) # es para que la letra sea temaño 1
sb.barplot(barras, preferencias)
# Out:
# c:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# barra horizontal
barras = ["chocolate","fresa","vainilla","pistacho"] # sabores de helados
preferencias = np.array([12,18,20,4]) # cuantos prefieren cada sabor
sb.barplot(preferencias, barras, orient= "h", palette= "pastel") #observa el cambio en las dos categorias
# Out:
# c:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# grafico de lineas serie tiempo
import pandas as pd

#creamos cuatro variables aleatorias
A = np.random.normal(10,3,50)
B = np.random.normal(11,3,50)
C = np.random.normal(12,3,50)
D = np.random.normal(13,3,50)

datos = pd.DataFrame({"A":A,"B":B,"C":C,"D":D}) # hace,os n dataframe con las cuatro columnas
sb.lineplot(data=datos, palette="bright", linewidth=1)
# Out:
# <AxesSubplot:>
