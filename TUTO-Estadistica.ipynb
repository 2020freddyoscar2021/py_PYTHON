# %%
import pandas as pd
df=pd.read_csv('StudentSurvey.csv')
df
# Out:
#           Year Sex Smoke    Award HigherSAT  Exercise    TV  Height  Weight  \
# 0       Senior   M    No  Olympic      Math      10.0   1.0    71.0   180.0
# 1    Sophomore   F   Yes  Academy      Math       4.0   7.0    66.0   120.0
# 2    FirstYear   M    No    Nobel      Math      14.0   5.0    72.0   208.0
# 3       Junior   M    No    Nobel      Math       3.0   1.0    63.0   110.0
# 4    Sophomore   F    No    Nobel    Verbal       3.0   3.0    65.0   150.0
# ..         ...  ..   ...      ...       ...       ...   ...     ...     ...
# 357  Sophomore   F   Yes    Nobel    Verbal       2.0   0.0    83.0   130.0
# 358  Sophomore   M   Yes  Olympic      Math       8.0  10.0    61.0   180.0
# 359  Sophomore   F   Yes    Nobel    Verbal       1.0   1.0    65.0   150.0
# 360  FirstYear   M   Yes  Olympic    Verbal      14.0   5.0    77.0   205.0
# 361  Sophomore   F   Yes  Olympic      Math      12.0   5.0    60.0   115.0
#
# ...

# %%
grupo_genero = df.groupby('Sex')
grupo_genero.mean()
# Out:
#      Exercise        TV     Height      Weight  Siblings  BirthOrder  \
# Sex
# F    8.110119  5.236686  65.694611  138.375758  1.721893    1.916168
# M    9.875648  7.619792  70.845745  178.208333  1.730570    1.755208
#
#       VerbalSAT     MathSAT          SAT       GPA      Pulse  Piercings
# Sex
# F    594.301775  599.177515  1193.479290  3.235556  71.644970   3.378698
# M    594.093264  618.419689  1212.512953  3.089235  67.761658   0.171875

# %%
grupo_genero.median()
# Out:
#      Exercise   TV  Height  Weight  Siblings  BirthOrder  VerbalSAT  MathSAT  \
# Sex
# F         7.0  4.0    65.0   138.0       1.0         2.0      600.0    600.0
# M        10.0  5.0    71.0   175.0       2.0         1.5      600.0    620.0
#
#         SAT    GPA  Pulse  Piercings
# Sex
# F    1200.0  3.255   72.0        3.0
# M    1220.0  3.100   68.0        0.0

# %%
grupo_genero.count()
# Out:
#      Year  Smoke  Award  HigherSAT  Exercise   TV  Height  Weight  Siblings  \
# Sex
# F     167    169    169        165       168  169     167     165       169
# M     193    193    193        190       193  192     188     192       193
#
#      BirthOrder  VerbalSAT  MathSAT  SAT  GPA  Pulse  Piercings
# Sex
# F           167        169      169  169  162    169        169
# M           192        193      193  193  183    193        192

# %%
grupo_genero.boxplot(column=['VerbalSAT','MathSAT'])
# Out:
# F         AxesSubplot(0.1,0.15;0.363636x0.75)
# M    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
import pandas.plotting
pd.plotting.scatter_matrix(df[['VerbalSAT','MathSAT','SAT']], color='green')

import matplotlib.pyplot as plt
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as pyplot

df4 = pd.DataFrame({})
