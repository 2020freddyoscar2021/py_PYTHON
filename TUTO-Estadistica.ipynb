# %%
import pandas as pd
df=pd.read_csv('c:\\Users\\User\\py_Codigo\\py_PYTHON\\FundamentalsOfDataAnalysisInLanguageR\\StudentSurvey.csv')
df
# Out:
#       ID  gender  age classification  name_letters  happy  concerts  \
# 0      1    Male   17       Freshman             4     80         2
# 1      2  Female   19      Sophomore             8     76        15
# 2      3  Female   18       Freshman             6     50         3
# 3      4    Male   19      Sophomore             4     75         0
# 4      5  Female   19      Sophomore             7     89         1
# ..   ...     ...  ...            ...           ...    ...       ...
# 374  375  Female   18       Freshman             3     90         1
# 375  376  Female   19       Freshman             6     80         0
# 376  377    Male   19      Sophomore             7     75         1
# 377  378  Female   18       Freshman             4     20         0
# 378  379  Female   19      Sophomore             9     50         0
#
#     hair_color  own_shoes greek live_campus  roomates  austin  birth_month  \
# ...

# %%
grupo_genero = df.groupby('gender')
grupo_genero.mean()
# Out:
#                 ID        age  name_letters      happy  concerts  own_shoes  \
# gender
# Female  194.373457  19.104938      6.049383  78.549383  2.311728  19.679012
# Male    164.236364  20.145455      5.509091  75.000000  1.727273  11.254545
#
#         roomates    austin  birth_month
# gender
# Female  1.583333  8.384259     6.814815
# Male    1.527273  8.427273     7.018182

# %%
grupo_genero.median()
# Out:
#            ID   age  name_letters  happy  concerts  own_shoes  roomates  \
# gender
# Female  193.5  19.0           6.0   80.0       1.0       17.0       1.0
# Male    156.0  19.0           6.0   80.0       1.0        6.0       1.0
#
#         austin  birth_month
# gender
# Female     9.0          7.0
# Male       8.0          7.0

# %%
grupo_genero.count()
# Out:
#          ID  age  classification  name_letters  happy  concerts  hair_color  \
# gender
# Female  324  324             324           324    324       324         324
# Male     55   55              55            55     55        55          55
#
#         own_shoes  greek  live_campus  roomates  austin  birth_month  commute  \
# gender
# Female        324    324          324       324     324          324      324
# Male           55     55           55        55      55           55       55
#
#         car  sport
# gender
# Female  324    324
# Male     55     55

# %%
grupo_genero.boxplot(column=['austin','birth_month'])
# Out:
# Female         AxesSubplot(0.1,0.15;0.363636x0.75)
# Male      AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
import pandas.plotting
#Matrices de dispersión para ciertas columnas:
pd.plotting.scatter_matrix(df[['austin','birth_month','concerts']], color='green')

import matplotlib.pyplot as plt
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as pyplot

df4 = pd.DataFrame({})
